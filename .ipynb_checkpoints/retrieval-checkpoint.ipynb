# %%
import os
import time
import pickle
import streamlit as st
import langchain
from langchain_nvidia_ai_endpoints import ChatNVIDIA
from langchain_nvidia_ai_endpoints import NVIDIAEmbeddings
from langchain_openai import OpenAI
from langchain_openai import OpenAIEmbeddings

from langchain_classic.chains import RetrievalQAWithSourcesChain
from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_community.document_loaders import UnstructuredURLLoader
from langchain_community.vectorstores import FAISS

# %%
import langchain
print(langchain.__version__)
print(langchain.__file__)
# Out:
# 1.3.14
# C:\Users\addwi\AppData\Local\Programs\Python\Python314\Lib\site-packages\langchain\__init__.py

# %%
pip install langchain-nvidia-ai-endpoints
# Out:
# Collecting langchain-nvidia-ai-endpoints
#   Downloading langchain_nvidia_ai_endpoints-1.4.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: aiohttp<3.15.0,>=3.13.3 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langchain-nvidia-ai-endpoints) (3.14.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langchain-nvidia-ai-endpoints) (1.4.9)
# Requirement already satisfied: requests>=2.28.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langchain-nvidia-ai-endpoints) (2.33.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from aiohttp<3.15.0,>=3.13.3->langchain-nvidia-ai-endpoints) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from aiohttp<3.15.0,>=3.13.3->langchain-nvidia-ai-endpoints) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from aiohttp<3.15.0,>=3.13.3->langchain-nvidia-ai-endpoints) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from aiohttp<3.15.0,>=3.13.3->langchain-nvidia-ai-endpoints) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from aiohttp<3.15.0,>=3.13.3->langchain-nvidia-ai-endpoints) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from aiohttp<3.15.0,>=3.13.3->langchain-nvidia-ai-endpoints) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from aiohttp<3.15.0,>=3.13.3->langchain-nvidia-ai-endpoints) (1.24.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (0.9.7)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (4.14.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (3.8.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (0.25.0)
# Requirement already satisfied: certifi in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (1.0.9)
# Requirement already satisfied: idna in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.7->langchain-nvidia-ai-endpoints) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.28.0->langchain-nvidia-ai-endpoints) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.28.0->langchain-nvidia-ai-endpoints) (2.6.3)
# Downloading langchain_nvidia_ai_endpoints-1.4.3-py3-none-any.whl (64 kB)
# Installing collected packages: langchain-nvidia-ai-endpoints
# Successfully installed langchain-nvidia-ai-endpoints-1.4.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.59.2-py3-none-any.whl.metadata (9.6 kB)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0 (from streamlit)
#   Downloading altair-6.2.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (1.9.0)
# Collecting cachetools<8,>=5.5 (from streamlit)
#   Downloading cachetools-7.1.4-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (8.4.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.52-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (2.4.6)
# Requirement already satisfied: packaging>=20 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<4,>=1.4.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (12.1.1)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.3-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting protobuf<8,>=3.20 (from streamlit)
#   Downloading protobuf-7.35.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Collecting pyarrow<25,>=7.0 (from streamlit)
#   Downloading pyarrow-24.0.0-cp314-cp314-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (2.33.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (8.5.0)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: starlette>=0.40.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (1.3.1)
# Requirement already satisfied: uvicorn>=0.30.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (0.49.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio>=4.0.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (4.14.0)
# Requirement already satisfied: python-multipart>=0.0.10 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (0.0.32)
# Requirement already satisfied: websockets>=12.0.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (15.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (2.2.0)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: jinja2 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.24.0)
# Requirement already satisfied: colorama in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2026.6.3)
# Requirement already satisfied: six>=1.5 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: h11>=0.8 in c:\users\addwi\appdata\local\programs\python\python314\lib\site-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)
# Downloading streamlit-1.59.2-py3-none-any.whl (10.3 MB)
#    ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.3 MB 2.6 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/10.3 MB 2.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/10.3 MB 2.1 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/10.3 MB 1.7 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/10.3 MB 1.7 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/10.3 MB 1.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.6/10.3 MB 1.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.9/10.3 MB 1.7 MB/s eta 0:00:05
#    ------------ --------------------------- 3.1/10.3 MB 1.7 MB/s eta 0:00:05
#    ------------- -------------------------- 3.4/10.3 MB 1.7 MB/s eta 0:00:05
#    --------------- ------------------------ 3.9/10.3 MB 1.7 MB/s eta 0:00:04
#    ------------------ --------------------- 4.7/10.3 MB 1.8 MB/s eta 0:00:04
#    -------------------- ------------------- 5.2/10.3 MB 1.9 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.8/10.3 MB 1.9 MB/s eta 0:00:03
#    ------------------------- -------------- 6.6/10.3 MB 2.0 MB/s eta 0:00:02
#    --------------------------- ------------ 7.1/10.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 7.9/10.3 MB 2.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.9/10.3 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.0/10.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 10.3/10.3 MB 2.5 MB/s  0:00:04
# Downloading altair-6.2.2-py3-none-any.whl (797 kB)
#    ---------------------------------------- 0.0/797.6 kB ? eta -:--:--
#    ---------------------------------------- 797.6/797.6 kB 8.9 MB/s  0:00:00
# Downloading cachetools-7.1.4-py3-none-any.whl (16 kB)
# Downloading gitpython-3.1.52-py3-none-any.whl (215 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading protobuf-7.35.1-cp310-abi3-win_amd64.whl (439 kB)
# Downloading pyarrow-24.0.0-cp314-cp314-win_amd64.whl (28.0 MB)
#    ---------------------------------------- 0.0/28.0 MB ? eta -:--:--
#    - -------------------------------------- 0.8/28.0 MB 4.9 MB/s eta 0:00:06
#    --- ------------------------------------ 2.4/28.0 MB 7.4 MB/s eta 0:00:04
#    ------- -------------------------------- 5.5/28.0 MB 9.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 7.6/28.0 MB 9.8 MB/s eta 0:00:03
#    ------------- -------------------------- 9.2/28.0 MB 9.4 MB/s eta 0:00:03
#    -------------- ------------------------- 10.5/28.0 MB 8.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 12.1/28.0 MB 8.7 MB/s eta 0:00:02
#    ------------------- -------------------- 13.4/28.0 MB 8.2 MB/s eta 0:00:02
#    -------------------- ------------------- 14.7/28.0 MB 8.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 15.7/28.0 MB 7.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 16.8/28.0 MB 7.3 MB/s eta 0:00:02
#    -------------------------- ------------- 18.4/28.0 MB 7.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 20.2/28.0 MB 7.4 MB/s eta 0:00:02
#    ------------------------------- -------- 22.3/28.0 MB 7.6 MB/s eta 0:00:01
#    ------------------------------------ --- 25.7/28.0 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  27.8/28.0 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 28.0/28.0 MB 8.2 MB/s  0:00:03
# Downloading pydeck-0.9.3-py2.py3-none-any.whl (11.4 MB)
#    ---------------------------------------- 0.0/11.4 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/11.4 MB 11.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.4/11.4 MB 8.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.6/11.4 MB 10.7 MB/s eta 0:00:01
#    ------------------------------- -------- 8.9/11.4 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.4 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.4/11.4 MB 10.8 MB/s  0:00:01
# Downloading smmap-5.0.3-py3-none-any.whl (24 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Installing collected packages: watchdog, toml, smmap, pyarrow, protobuf, cachetools, pydeck, gitdb, gitpython, altair, streamlit
#
#    ----------------------------------------  0/11 [watchdog]
#    ----------------------------------------  0/11 [watchdog]
#    ----------------------------------------  0/11 [watchdog]
#    ----------------------------------------  0/11 [watchdog]
#    ----------------------------------------  0/11 [watchdog]
#    --- ------------------------------------  1/11 [toml]
#    ------- --------------------------------  2/11 [smmap]
#    ------- --------------------------------  2/11 [smmap]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    ---------- -----------------------------  3/11 [pyarrow]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    -------------- -------------------------  4/11 [protobuf]
#    ------------------ ---------------------  5/11 [cachetools]
#    --------------------- ------------------  6/11 [pydeck]
#    --------------------- ------------------  6/11 [pydeck]
#    --------------------- ------------------  6/11 [pydeck]
#    --------------------- ------------------  6/11 [pydeck]
#    --------------------- ------------------  6/11 [pydeck]
#    --------------------- ------------------  6/11 [pydeck]
#    --------------------- ------------------  6/11 [pydeck]
#    ------------------------- --------------  7/11 [gitdb]
#    ------------------------- --------------  7/11 [gitdb]
#    ------------------------- --------------  7/11 [gitdb]
#    ------------------------- --------------  7/11 [gitdb]
#    ----------------------------- ----------  8/11 [gitpython]
#    ----------------------------- ----------  8/11 [gitpython]
#    ----------------------------- ----------  8/11 [gitpython]
#    ----------------------------- ----------  8/11 [gitpython]
#    ----------------------------- ----------  8/11 [gitpython]
#    ----------------------------- ----------  8/11 [gitpython]
#    ----------------------------- ----------  8/11 [gitpython]
#    ----------------------------- ----------  8/11 [gitpython]
#    -------------------------------- -------  9/11 [altair]
#    -------------------------------- -------  9/11 [altair]
#    -------------------------------- -------  9/11 [altair]
#    -------------------------------- -------  9/11 [altair]
#    -------------------------------- -------  9/11 [altair]
#    -------------------------------- -------  9/11 [altair]
#    -------------------------------- -------  9/11 [altair]
#    -------------------------------- -------  9/11 [altair]
#    -------------------------------- -------  9/11 [altair]
#    -------------------------------- -------  9/11 [altair]
#    -------------------------------- -------  9/11 [altair]
#    -------------------------------- -------  9/11 [altair]
#    -------------------------------- -------  9/11 [altair]
#    -------------------------------- -------  9/11 [altair]
#    -------------------------------- -------  9/11 [altair]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ------------------------------------ --- 10/11 [streamlit]
#    ---------------------------------------- 11/11 [streamlit]
#
# Successfully installed altair-6.2.2 cachetools-7.1.4 gitdb-4.0.12 gitpython-3.1.52 protobuf-7.35.1 pyarrow-24.0.0 pydeck-0.9.3 smmap-5.0.3 streamlit-1.59.2 toml-0.10.2 watchdog-6.0.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
os.environ["NVIDIA_API_KEY"] = "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"

# %%
# Initialise LLM with required params
llm = ChatNVIDIA(temperature=0.9, max_tokens=500)
# Out:
# C:\Users\addwi\AppData\Local\Temp\ipykernel_9944\1160162713.py:2: DeprecationWarning: The 'max_tokens' parameter is deprecated and will be removed in a future version. Please use 'max_completion_tokens' instead.
#   llm = ChatNVIDIA(temperature=0.9, max_tokens=500)

# %% [markdown]
# (1) Load data

# %%
loaders = UnstructuredURLLoader(urls=[
    "https://www.moneycontrol.com/news/business/markets/wall-street-rises-as-tesla-soars-on-ai-optimism-11351111.html",
    "https://www.moneycontrol.com/news/business/tata-motors-launches-punch-icng-price-starts-at-rs-7-1-lakh-11098751.html"
])
data = loaders.load() 
len(data)
# Out:
# 2

# %% [markdown]
# (2) Split data to create chunks

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

# As data is of type documents we can directly use split_documents over split_text in order to get the chunks.
docs = text_splitter.split_documents(data)

# %%
len(docs)
# Out:
# 19

# %%
docs[0]
# Out:
# Document(metadata={'source': 'https://www.moneycontrol.com/news/business/markets/wall-street-rises-as-tesla-soars-on-ai-optimism-11351111.html'}, page_content='English\n\nHindi\n\nGujarati\n\nSpecials\n\nLoans @ 9.99% in Just 5 Mins\n\nMy Alerts\n\nGo Ad-Free\n\nHello, Login\n\nHello, Login\n\nLog-inor Sign-Up\n\nMy Account\n\nMy Profile\n\nMy Portfolio\n\nMy Watchlist\n\nMy Alerts\n\nMy Messages\n\nPrice Alerts\n\nMy Profile\n\nMy PRO\n\nMy Portfolio\n\nMy Watchlist\n\nMy Alerts\n\nMy Messages\n\nPrice Alerts\n\nLogout\n\nLoans up to ₹50 LAKHS\n\nFixed Deposits\n\nCredit CardsLifetime Free\n\nCredit Score\n\nLoan against MFs\n\nChat with Us\n\nDownload App\n\nFollow us on:\n\nNetwork 18\n\n>->MC_ENG_DESKTOP/MC_ENG_NEWS/MC_ENG_MARKETS_AS/MC_ENG_ROS_NWS_MKTS_AS_ATF_728\n\nMoneycontrol\n\nGo PRO NowPRO\n\nMoneycontrol AD Lite\n\nMoneycontrol AD Lite\n\nMoneycontrol PRO\n\nMoneycontrol Super PRO\n\nAdvertisement\n\nRemove Ad\n\nBusiness\n\nMarkets\n\nStocks\n\nEconomy\n\nCompanies\n\nTrends\n\nIPO\n\nOpinion\n\nEV Special\n\nEco Pulse\n\nMC Learn\n\nPersonal Loan Offers\n\nPersonal Loan Offers\n\nTrending Topics\n\nSensex Today\n\nMeesho Share Price\n\nIndigo Share Price\n\nShoppers Stop Share Price\n\nEternal Share Price')

# %% [markdown]
# 3) Create embeddings for these chunks and save them to FAISS index

# %%
embeddings = NVIDIAEmbeddings()

vectorindex_openai = FAISS.from_documents(docs, embeddings)

# %%
# Storing vector index create in local
file_path="vector_index.pkl"
with open(file_path, "wb") as f:
    pickle.dump(vectorindex_openai, f)

# %%
if os.path.exists(file_path):
    with open(file_path, "rb") as f:
        vectorIndex = pickle.load(f)

# %% [markdown]
# 4) Retrieve similar embeddings for a given question and call LLM to retrieve final answer

# %%
chain = RetrievalQAWithSourcesChain.from_llm(llm=llm, retriever=vectorIndex.as_retriever())
chain
# Out:
# RetrievalQAWithSourcesChain(verbose=False, combine_documents_chain=MapReduceDocumentsChain(verbose=False, llm_chain=LLMChain(verbose=False, prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='Use the following portion of a long document to see if any of the text is relevant to answer the question.\nReturn any relevant text verbatim.\n{context}\nQuestion: {question}\nRelevant text, if any:'), llm=ChatNVIDIA(metadata={'lc_versions': {'langchain-core': '1.4.9', 'langchain': '1.3.14', 'langchain-nvidia-ai-endpoints': '1.4.3'}}, profile={'max_input_tokens': 131072, 'max_output_tokens': 131072, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True}, base_url='https://integrate.api.nvidia.com/v1', model='nvidia/nemotron-3-nano-30b-a3b', temperature=0.9, max_tokens=500, default_headers={}, model_kwargs={}), output_parser=StrOutputParser(), llm_kwargs={}), reduce_documents_chain=ReduceDocumentsChain(verbose=False, combine_documents_chain=StuffDocumentsChain(verbose=False, llm_chain=LLMChain(verbose=False, prompt=PromptTemplate(input_variables=['question', 'summaries'], input_types={}, partial_variables={}, template='Given the following extracted parts of a long document and a question, create a final answer with references ("SOURCES").\nIf you don\'t know the answer, just say that you don\'t know. Don\'t try to make up an answer.\nALWAYS return a "SOURCES" part in your answer.\n\nQUESTION: Which state/country\'s law governs the interpretation of the contract?\n=========\nContent: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.\nSource: 28-pl\nContent: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.\n\n11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.\n\n11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.\n\n11.9 No Third-Party Beneficiaries.\nSource: 30-pl\nContent: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,\nSource: 4-pl\n=========\nFINAL ANSWER: This Agreement is governed by English law.\nSOURCES: 28-pl\n\nQUESTION: What did the president say about Michael Jackson?\n=========\nContent: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia\'s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, ...

# %%
query = "what is the price of Tiago iCNG?"
# query = "what are the main features of Punch iCNG?"

langchain.debug = True

# Run the chain and store the output
result = chain({"question": query}, return_only_outputs=True)

# Print only the answer
print("Answer:")
print(result["answer"])

# Print the source
print("\nSource:")
print(result["sources"])
# Out:
# Answer:
# FINAL ANSWER: The Tiago iCNG is priced between Rs 6.55 lakh and Rs 8.1 lakh.
#
#
#
# Source:
# https://www.moneycontrol.com/news/business/tata-motors-launches-punch-icng-price-starts-at-rs-7-1-lakh-11098751.html
